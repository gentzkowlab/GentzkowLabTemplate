# %% [markdown]
# # Test Notebook with Error
#
# This notebook will intentionally fail during execution.

# %%
import time
import sys

print("Notebook starting...")
print("This cell executes successfully")

# %%
print("\nOutputting multiple lines to test real-time logging:")
for i in range(5):
    print(f"  Line {i+1} of output")
    time.sleep(0.5)

# %%
print("\nNow encountering an error...")
time.sleep(1)

# Intentional error
raise RuntimeError("ERROR: Something went wrong in the notebook!")

# %% [markdown]
# ## This cell should never execute
#
# Because the previous cell raised an error.

# %%
print("This line should never be reached")
